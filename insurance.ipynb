# %% [markdown]
# <a href="https://colab.research.google.com/github/BNavya1995/insurance_dataset/blob/main/insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "/content/new_insurance_data (1).csv"
df = pd.read_csv(url)
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
df.shape
# Out:
# (1338, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
df.describe()
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1329.000000  1335.000000  1333.000000   1324.000000
# mean     39.310008    30.665112     1.090773  33361.327180
# std      14.034818     6.101690     1.201856  15617.288337
# min      18.000000    15.960000     0.000000   1920.136268
# 25%      27.000000    26.302500     0.000000  20768.860390
# 50%      39.000000    30.400000     1.000000  33700.310675
# 75%      51.000000    34.687500     2.000000  45052.331957
# max      64.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1332.000000  1.335000e+03          1.334000e+03
# mean            15.216216  9.100047e+05          1.584179e+07
# std              7.467723  9.188612e+04          2.669305e+07
# min              1.000000  6.954300e+05          2.945253e+04
# 25%              9.000000  8.471995e+05          4.077633e+06
# ...

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df.drop_duplicates().sum()
# Out:
# age                                                                          52243.0
# sex                                malemalemalemalemalemalemalemalemalemalemalema...
# bmi                                                                        40937.925
# children                                                                      1454.0
# smoker                             nonononononononononononononononononononononono...
# Claim_Amount                                                         44170397.186456
# past_consultations                                                           20268.0
# num_of_steps                                                            1214856269.0
# Hospital_expenditure                                              21132950453.337234
# NUmber_of_past_hospitalizations                                               1417.0
# Anual_Salary                                                     492420233124.892029
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
df.isnull().sum() *100/df.shape[0]
# Out:
# age                                0.0
# sex                                0.0
# bmi                                0.0
# children                           0.0
# smoker                             0.0
# Claim_Amount                       0.0
# past_consultations                 0.0
# num_of_steps                       0.0
# Hospital_expenditure               0.0
# NUmber_of_past_hospitalizations    0.0
# Anual_Salary                       0.0
# region                             0.0
# charges                            0.0
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
for i in df.columns:
  if df[i].dtype =='object':
    df[i]= le.fit_transform(df[i])
# Out:
# /tmp/ipykernel_2395/4016106237.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]= le.fit_transform(df[i])
# /tmp/ipykernel_2395/4016106237.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i]= le.fit_transform(df[i])
# /tmp/ipykernel_2395/4016106237.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df=df.dropna()

# %%
import matplotlib.pyplot as plt

smoker=df[df['smoker']=='yes']
non_smoker=df[df['smoker']=='no']
plt.xlabel("charges")
plt.ylabel("bmi")

plt.title("Relation between charges and bmi")
plt.scatter(smoker['charges'],smoker['bmi'], color="blue")
plt.scatter(non_smoker['charges'],non_smoker['bmi'], color='red')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_2395/1818060965.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.boxplot([df['age'],df['charges']])
plt.xlabel("clomns")
plt.ylabel("values")
plt.title("distibtion btw ages and charges" )
# Out:
# Text(0.5, 1.0, 'distibtion btw ages and charges')

# %%
smoker=df[df['smoker']=='yes']
non_smoker=df[df['smoker']=='no']
plt.xlabel("age")
plt.ylabel("charges")

plt.title("Relation between charges and age")
plt.scatter(smoker['age'],smoker['charges'], color="blue")
plt.scatter(non_smoker['age'],non_smoker['charges'], color='red')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_2395/887551553.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.groupby('region')['charges'].mean()
# Out:
# region
# northeast    13528.481783
# northwest    12499.871674
# southeast    14569.425864
# southwest    12730.917679
# Name: charges, dtype: float64

# %%
print(df.groupby('region')[['bmi', 'smoker']].value_counts(normalize=True))
# OR just check the average BMI per region:
print(df.groupby('region')['bmi'].mean())
# Out:
# region     bmi     smoker
# northeast  25.460  no        0.018519
#            32.300  no        0.018519
#            22.135  no        0.012346
#            27.360  no        0.012346
#            28.785  no        0.012346
#                                ...
# southwest  44.000  no        0.003077
#            44.700  no        0.003077
#            45.900  no        0.003077
#            46.700  no        0.003077
#            47.600  yes       0.003077
# Name: proportion, Length: 844, dtype: float64
# region
# northeast    29.173503
# northwest    29.195494
# southeast    33.355989
# southwest    30.596615
# Name: bmi, dtype: float64

# %%
x=df['age']
plt.xlabel("age")
plt.ylabel("frequency")
plt.title("Age Distribution")
plt.hist(x,bins=8, color='green',edgecolor='red')
# Out:
# (array([249., 167., 157., 127., 166., 173., 159., 139.]),
#  array([18.  , 23.75, 29.5 , 35.25, 41.  , 46.75, 52.5 , 58.25, 64.  ]),
#  <BarContainer object of 8 artists>)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection  import train_test_split
from sklearn.metrics import *


x=df.drop(columns=['charges'])
y=df['charges']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from sklearn.preprocessing  import StandardScaler
scaler= StandardScaler()
x_train_sr = scaler.fit_transform(x_train)
x_test_sr = scaler.transform(x_test)

# %%
ml=LinearRegression()

# %%
ml.fit(x_train_sr,y_train)
# Out:
# LinearRegression()

# %%
y_pred=ml.predict(x_test_sr)

# %%
y_pred
# Out:
# array([44621.00271916,  5316.13148472, 14795.07099049,  7543.39703373,
#        40121.2003364 , 13198.08906907,  4383.2275159 ,  7863.14773878,
#         3912.45710523,  7545.5829857 , 10979.60922558,  7025.00962486,
#          522.06595988,  1096.90908898,  4693.48944509,  5045.87857944,
#         9428.10827865,  6668.8673727 ,  3925.15374304, 33006.07783891,
#         8542.77885967,  7998.40727008,  9927.19442758,  9298.79482716,
#         4658.24908212,  2857.95019674,  7371.96648514,  4923.64328174,
#         9144.73818957,  7284.59030373,  1055.46421715, 44521.99452072,
#        10196.02915844,  1901.95771194, 25487.67033218, 12990.80974363,
#         1662.18150964, 31501.35295229, 21792.37454188, 11909.56812845,
#         7001.84118239, 33897.46892286, 18828.31985643,  -220.01709486,
#         7885.96734678, 48002.7781608 ,  5192.45316736,  1877.14465171,
#        11219.82771538, 38496.4162841 ,  5970.96270807, 10349.84056162,
# ...

# %%
result = pd.DataFrame({'actual':y_test,'predicted':y_pred})
result
# Out:
#            actual     predicted
# 1294  44260.74990  44621.002719
# 358    4992.37640   5316.131485
# 980   15006.57945  14795.070990
# 446    6272.47720   7543.397034
# 1251  39611.75770  40121.200336
# ...           ...           ...
# 838   11881.96960  11396.071556
# 571    8023.13545   7916.617874
# 1035  18765.87545  19051.804378
# 900   12979.35800  12777.227886
# 1143  25678.77845  25220.446164
#
# [258 rows x 2 columns]

# %%
mae=mean_absolute_error(y_pred,y_test)
mae
# Out:
# 783.9331373820315

# %%
mse=mean_squared_error(y_pred,y_test)
mse
# Out:
# 989199.4206319898

# %%
import numpy as np
rmse=np.sqrt(mse)
rmse
# Out:
# np.float64(994.5850494713812)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.9937167161942061

# %%
import seaborn as sns
sns.regplot(x = y_pred,y=y_test)
plt.show()
